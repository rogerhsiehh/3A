# %% [markdown]
# # 0. Install Dependencies

# %%
# !pip install tensorflow
# !pip install gym
# !pip install keras
# !pip install keras-rl2
# !pip install stable-baselines3

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # 1. Create environment follows Gym that SB3 supports

# %%
import random
import numpy as np
import gymnasium as gym
from gymnasium import spaces

class TaxiChargingEnv(gym.Env):
    def __init__(self):
        super(TaxiChargingEnv, self).__init__()
        # Actions we take: 0 kW, 7 kW, 14 kW, 22 kW
        self.action_space = spaces.Discrete(4)
        # State represents battery charge level (kWh)
        self.observation_space = spaces.Box(low=np.array([0]), high=np.array([100]), dtype=np.float32)
        # Initialize state
        self.state = 0.0
        # Battery capacity
        self.battery_capacity = 100.0  # kWh
        # Initial battery level
        self.battery_level = float(random.randint(20, 30))
        # Charging period (2 hours, every 15 minutes = 8 steps)
        self.steps_left = 8
        # Energy demand parameters
        self.mu = 30.0  # kWh
        self.sigma = 5.0  # kWh
        # Time coefficient for cost function
        self.alpha = 1

    def step(self, action):
        charging_rates = [0, 7, 14, 22]  # kW for each action
        power = charging_rates[action]

        # Calculate cost: charging cost (t,p) = 𝛼𝑡 * e^𝑝
        cost = self.alpha * np.exp(power/10)

        # Update battery level
        self.battery_level = min(self.battery_level + power / 4, self.battery_capacity) # each time 15 min, power * 15min = power * 1hour / 4

        # Reduce the steps left by 1
        self.steps_left -= 1

        # If steps are finished, calculate if the battery meets the demand
        if self.steps_left == 0:
            demand = np.random.normal(self.mu, self.sigma)
            if self.battery_level >= demand:
                reward = -cost  # Minimize cost, no penalty for meeting demand
            else:
                reward = -cost - 1000  # High penalty for not meeting demand
            terminated = True
        else:
            reward = -cost  # Incur cost for charging, continue episode
            terminated = False

        # Always set truncated to False in this environment
        truncated = False

        # State is the current battery level
        self.state = np.array([self.battery_level], dtype=np.float32)

        # Info dictionary
        info = {
            "battery_level": self.battery_level,
            "cost": cost
        }

        return self.state, reward, terminated, truncated, info

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        # Reset battery level
        self.battery_level = float(random.randint(20, 30))
        # Reset steps left
        self.steps_left = 8
        # Reset state
        self.state = np.array([self.battery_level], dtype=np.float32)
        return self.state, {}

    def render(self, mode='human', close=False):
        # For visualization, if needed
        pass

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Parameters for the normal distribution
mu = 30.0  # Mean energy demand in kWh
sigma = 5.0  # Standard deviation in kWh

# Generate x values
x = np.linspace(mu - 4*sigma, mu + 4*sigma, 1000)

# Calculate the PDF of the normal distribution
pdf = norm.pdf(x, mu, sigma)

# Plot
plt.figure(figsize=(10, 6))
plt.plot(x, pdf, label=f'Normal Distribution\n$\mu={mu}$, $\sigma={sigma}$')
plt.fill_between(x, pdf, alpha=0.2)
plt.xlabel('Energy Demand (kWh)')
plt.ylabel('Probability Density')
plt.title('Normal Distribution of Energy Demand')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Parameters
mu = 30.0  # Mean energy demand in kWh
sigma = 5.0  # Standard deviation in kWh
steps = 8  # Number of time steps

# Generate energy demand over time
np.random.seed(0)  # For reproducibility
energy_demand = np.random.normal(loc=mu, scale=sigma, size=steps)

# Time steps (assuming each step is 15 minutes, for simplicity we use integers)
time_steps = np.arange(1, steps + 1)

# Plot
plt.figure(figsize=(10, 6))
plt.plot(time_steps, energy_demand, marker='o', linestyle='-', color='b')
plt.xlabel('Time Step (15 minutes intervals)')
plt.ylabel('Energy Demand (kWh)')
plt.title('Energy Demand Over Time')
plt.grid(True)
plt.show()

# %%
# Create the environment
env = TaxiChargingEnv()

# %% [markdown]
# # 2. Validate and test the environment

# %%
#Check if the environment follow Gym interface that SB3 support
from stable_baselines3.common.env_checker import check_env
check_env(env)

# %%
obs, _ = env.reset()
env.render()

print(env.observation_space)
print(env.action_space)
print(env.action_space.sample())

# Random agent
n_steps = 8
for step in range(n_steps):
    action = env.action_space.sample()  # Random action
    print(f"Step {step + 1}")
    obs, reward, terminated, truncated, info = env.step(action)
    done = terminated or truncated
    print("obs=", obs, "reward=", reward, "done=", done, "info=", info)
    env.render()
    if done:
        print("Goal reached!", "reward=", reward)
        break
# Out:
# Box(0.0, 100.0, (1,), float32)
# Discrete(4)
# 0
# Step 1
# obs= [30.5] reward= -9.025013499434122 done= False info= {'battery_level': 30.5, 'cost': 9.025013499434122}
# Step 2
# obs= [34.] reward= -4.0551999668446745 done= False info= {'battery_level': 34.0, 'cost': 4.0551999668446745}
# Step 3
# obs= [39.5] reward= -9.025013499434122 done= False info= {'battery_level': 39.5, 'cost': 9.025013499434122}
# Step 4
# obs= [39.5] reward= -1.0 done= False info= {'battery_level': 39.5, 'cost': 1.0}
# Step 5
# obs= [43.] reward= -4.0551999668446745 done= False info= {'battery_level': 43.0, 'cost': 4.0551999668446745}
# Step 6
# obs= [44.75] reward= -2.0137527074704766 done= False info= {'battery_level': 44.75, 'cost': 2.0137527074704766}
# Step 7
# obs= [46.5] reward= -2.0137527074704766 done= False info= {'battery_level': 46.5, 'cost': 2.0137527074704766}
# Step 8
# obs= [46.5] reward= -1.0 done= True info= {'battery_level': 46.5, 'cost': 1.0}
# Goal reached! reward= -1.0

# %% [markdown]
# # 3. Stable-Baselines

# %%
from stable_baselines3.common.env_util import make_vec_env
vec_env = make_vec_env(lambda: env, n_envs=1)

# %% [markdown]
# ## 3.1 PPO

# %%
from stable_baselines3 import PPO

# %%
# Train the agent using PPO
model = PPO("MlpPolicy", vec_env, verbose=1) #Multi-Layer Perceptron Policy, which is a fully connected neural network. 
                                             #This policy will be used to approximate the Q-values in the PPO algorithm.
model.learn(total_timesteps=100000)
# Out:
# Using cpu device
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 8        |
# |    ep_rew_mean     | -41.4    |
# | time/              |          |
# |    fps             | 5814     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8           |
# |    ep_rew_mean          | -97.8       |
# | time/                   |             |
# |    fps                  | 3628        |
# |    iterations           | 2           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.020046968 |
# |    clip_fraction        | 0.365       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | -0.000138   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.15e+03    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0222     |
# |    value_loss           | 8.17e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8            |
# |    ep_rew_mean          | -57.8        |
# | time/                   |              |
# |    fps                  | 3363         |
# |    iterations           | 3            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0031117005 |
# |    clip_fraction        | 0.0464       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -1.56e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.18e+04     |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00822     |
# |    value_loss           | 3.93e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8           |
# |    ep_rew_mean          | -106        |
# | time/                   |             |
# |    fps                  | 3233        |
# |    iterations           | 4           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.012764491 |
# |    clip_fraction        | 0.176       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | -2.03e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.01e+04    |
# |    n_updates            | 30          |
# |    policy_gradient_loss | 0.00339     |
# |    value_loss           | 2.33e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8           |
# |    ep_rew_mean          | -84.9       |
# | time/                   |             |
# |    fps                  | 3159        |
# |    iterations           | 5           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.010951351 |
# |    clip_fraction        | 0.278       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | -3.46e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.81e+04    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00658    |
# |    value_loss           | 3.32e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8           |
# |    ep_rew_mean          | -76         |
# | time/                   |             |
# |    fps                  | 3098        |
# |    iterations           | 6           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.017496794 |
# |    clip_fraction        | 0.373       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | -1.67e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.81e+03    |
# |    n_updates            | 50          |
# |    policy_gradient_loss | 0.00553     |
# |    value_loss           | 2.81e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8            |
# |    ep_rew_mean          | -66.4        |
# | time/                   |              |
# |    fps                  | 3070         |
# |    iterations           | 7            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0055607962 |
# |    clip_fraction        | 0.00859      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | -5.96e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.85e+03     |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00348     |
# |    value_loss           | 3.8e+04      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8            |
# |    ep_rew_mean          | -84.3        |
# | time/                   |              |
# |    fps                  | 3052         |
# |    iterations           | 8            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0070737614 |
# |    clip_fraction        | 0.178        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.17        |
# |    explained_variance   | -4.77e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.21e+04     |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.000541    |
# |    value_loss           | 1.54e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8            |
# |    ep_rew_mean          | -45.3        |
# | time/                   |              |
# |    fps                  | 3032         |
# |    iterations           | 9            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0034600548 |
# |    clip_fraction        | 0.0414       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | -4.77e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.76e+04     |
# |    n_updates            | 80           |
# |    policy_gradient_loss | 5.53e-05     |
# |    value_loss           | 2.79e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8            |
# |    ep_rew_mean          | -29.2        |
# | time/                   |              |
# |    fps                  | 3019         |
# |    iterations           | 10           |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0079904515 |
# |    clip_fraction        | 0.25         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | -2.38e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.17e+04     |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00602     |
# |    value_loss           | 1.79e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8           |
# |    ep_rew_mean          | -39.7       |
# | time/                   |             |
# |    fps                  | 3009        |
# |    iterations           | 11          |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.008782412 |
# |    clip_fraction        | 0.0358      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | 6.56e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.01e+03    |
# |    n_updates            | 100         |
# |    policy_gradient_loss | 0.00133     |
# |    value_loss           | 1.29e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8           |
# |    ep_rew_mean          | -27.9       |
# | time/                   |             |
# |    fps                  | 3003        |
# |    iterations           | 12          |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.007534409 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.000968    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.67e+03    |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00273    |
# |    value_loss           | 7.86e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 8          |
# |    ep_rew_mean          | -36.6      |
# | time/                   |            |
# |    fps                  | 2996       |
# |    iterations           | 13         |
# |    time_elapsed         | 8          |
# |    total_timesteps      | 26624      |
# | train/                  |            |
# |    approx_kl            | 0.01866352 |
# |    clip_fraction        | 0.115      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.14      |
# |    explained_variance   | 0.00271    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 68         |
# |    n_updates            | 120        |
# |    policy_gradient_loss | -0.00948   |
# |    value_loss           | 5.3e+03    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8           |
# |    ep_rew_mean          | -34.7       |
# | time/                   |             |
# |    fps                  | 2988        |
# |    iterations           | 14          |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.016399032 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.961      |
# |    explained_variance   | 0.0027      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 55.5        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.012      |
# |    value_loss           | 7.81e+03    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 8             |
# |    ep_rew_mean          | -72.8         |
# | time/                   |               |
# |    fps                  | 2981          |
# |    iterations           | 15            |
# |    time_elapsed         | 10            |
# |    total_timesteps      | 30720         |
# | train/                  |               |
# |    approx_kl            | 0.00048094924 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.935        |
# |    explained_variance   | 0.00481       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 108           |
# |    n_updates            | 140           |
# |    policy_gradient_loss | -0.000564     |
# |    value_loss           | 1.29e+04      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8            |
# |    ep_rew_mean          | -56          |
# | time/                   |              |
# |    fps                  | 2979         |
# |    iterations           | 16           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0034125764 |
# |    clip_fraction        | 0.03         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.951       |
# |    explained_variance   | 0.00458      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.89e+04     |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00193     |
# |    value_loss           | 3.54e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8           |
# |    ep_rew_mean          | -54.5       |
# | time/                   |             |
# |    fps                  | 2948        |
# |    iterations           | 17          |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.010036847 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.00122     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.44e+04    |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00546    |
# |    value_loss           | 2.53e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8            |
# |    ep_rew_mean          | -76.2        |
# | time/                   |              |
# |    fps                  | 2945         |
# |    iterations           | 18           |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0017688826 |
# |    clip_fraction        | 0.000195     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | 0.00915      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 79.5         |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00109     |
# |    value_loss           | 1.02e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8            |
# |    ep_rew_mean          | -27.4        |
# | time/                   |              |
# |    fps                  | 2939         |
# |    iterations           | 19           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0008908742 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | 0.00941      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.42e+04     |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.000793    |
# |    value_loss           | 2.03e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8           |
# |    ep_rew_mean          | -62.3       |
# | time/                   |             |
# |    fps                  | 2933        |
# |    iterations           | 20          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.042994883 |
# |    clip_fraction        | 0.273       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.92       |
# |    explained_variance   | 0.0344      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.1        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0235     |
# |    value_loss           | 2.63e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8            |
# |    ep_rew_mean          | -61.7        |
# | time/                   |              |
# |    fps                  | 2930         |
# |    iterations           | 21           |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0016639925 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.876       |
# |    explained_variance   | 0.00779      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.2e+04      |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.000682    |
# |    value_loss           | 2.04e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8            |
# |    ep_rew_mean          | -41.1        |
# | time/                   |              |
# |    fps                  | 2928         |
# |    iterations           | 22           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0013307983 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.83        |
# |    explained_variance   | 0.0124       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.34e+04     |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.0012      |
# |    value_loss           | 2.28e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8            |
# |    ep_rew_mean          | -52.1        |
# | time/                   |              |
# |    fps                  | 2926         |
# |    iterations           | 23           |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0028786368 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.847       |
# |    explained_variance   | 0.0134       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 143          |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.000409    |
# |    value_loss           | 1.78e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8            |
# |    ep_rew_mean          | -51.7        |
# | time/                   |              |
# |    fps                  | 2927         |
# |    iterations           | 24           |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0015579478 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.886       |
# |    explained_variance   | 0.0174       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.41e+04     |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00146     |
# |    value_loss           | 2.77e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8            |
# |    ep_rew_mean          | -34          |
# | time/                   |              |
# |    fps                  | 2926         |
# |    iterations           | 25           |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0065611023 |
# |    clip_fraction        | 0.0281       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.919       |
# |    explained_variance   | 0.0118       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.45e+04     |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00265     |
# |    value_loss           | 2.02e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8           |
# |    ep_rew_mean          | -51.9       |
# | time/                   |             |
# |    fps                  | 2924        |
# |    iterations           | 26          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.010688035 |
# |    clip_fraction        | 0.0705      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.891      |
# |    explained_variance   | 0.0191      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 30.3        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00631    |
# |    value_loss           | 7.78e+03    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 8             |
# |    ep_rew_mean          | -81.5         |
# | time/                   |               |
# |    fps                  | 2923          |
# |    iterations           | 27            |
# |    time_elapsed         | 18            |
# |    total_timesteps      | 55296         |
# | train/                  |               |
# |    approx_kl            | 0.00038636292 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.86         |
# |    explained_variance   | 0.0131        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.61e+04      |
# |    n_updates            | 260           |
# |    policy_gradient_loss | -8.01e-05     |
# |    value_loss           | 2.26e+04      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8           |
# |    ep_rew_mean          | -33.9       |
# | time/                   |             |
# |    fps                  | 2924        |
# |    iterations           | 28          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.009222516 |
# |    clip_fraction        | 0.0941      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.931      |
# |    explained_variance   | 0.0181      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.54e+04    |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00509    |
# |    value_loss           | 3.73e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8           |
# |    ep_rew_mean          | -42.9       |
# | time/                   |             |
# |    fps                  | 2926        |
# |    iterations           | 29          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.010710165 |
# |    clip_fraction        | 0.0449      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.918      |
# |    explained_variance   | 0.0154      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.11e+04    |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00468    |
# |    value_loss           | 1.04e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8           |
# |    ep_rew_mean          | -41.7       |
# | time/                   |             |
# |    fps                  | 2927        |
# |    iterations           | 30          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.001712956 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.86       |
# |    explained_variance   | 0.00945     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.6e+03     |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00153    |
# |    value_loss           | 1.53e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8            |
# |    ep_rew_mean          | -51.6        |
# | time/                   |              |
# |    fps                  | 2927         |
# |    iterations           | 31           |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0048129316 |
# |    clip_fraction        | 0.0962       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.874       |
# |    explained_variance   | 0.017        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.8e+04      |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00402     |
# |    value_loss           | 2.26e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8            |
# |    ep_rew_mean          | -60.4        |
# | time/                   |              |
# |    fps                  | 2928         |
# |    iterations           | 32           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0106120575 |
# |    clip_fraction        | 0.0173       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.828       |
# |    explained_variance   | 0.0176       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.76e+03     |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00228     |
# |    value_loss           | 1.03e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8            |
# |    ep_rew_mean          | -51.7        |
# | time/                   |              |
# |    fps                  | 2930         |
# |    iterations           | 33           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0057255365 |
# |    clip_fraction        | 0.0702       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.786       |
# |    explained_variance   | 0.0184       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.32e+03     |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00288     |
# |    value_loss           | 2.01e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8            |
# |    ep_rew_mean          | -50.9        |
# | time/                   |              |
# |    fps                  | 2931         |
# |    iterations           | 34           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0088850055 |
# |    clip_fraction        | 0.0481       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.742       |
# |    explained_variance   | 0.0255       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 38.6         |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00215     |
# |    value_loss           | 7.82e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8            |
# |    ep_rew_mean          | -59.7        |
# | time/                   |              |
# |    fps                  | 2931         |
# |    iterations           | 35           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0028958532 |
# |    clip_fraction        | 0.00874      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.652       |
# |    explained_variance   | 0.013        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.51e+04     |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00161     |
# |    value_loss           | 2e+04        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8           |
# |    ep_rew_mean          | -91.1       |
# | time/                   |             |
# |    fps                  | 2932        |
# |    iterations           | 36          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.005359405 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.706      |
# |    explained_variance   | 0.0172      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.65e+04    |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00272    |
# |    value_loss           | 3.23e+04    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 8          |
# |    ep_rew_mean          | -62.3      |
# | time/                   |            |
# |    fps                  | 2932       |
# |    iterations           | 37         |
# |    time_elapsed         | 25         |
# |    total_timesteps      | 75776      |
# | train/                  |            |
# |    approx_kl            | 0.00545393 |
# |    clip_fraction        | 0.104      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.771     |
# |    explained_variance   | 0.0155     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.23e+04   |
# |    n_updates            | 360        |
# |    policy_gradient_loss | -0.00384   |
# |    value_loss           | 2.99e+04   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8           |
# |    ep_rew_mean          | -62.8       |
# | time/                   |             |
# |    fps                  | 2931        |
# |    iterations           | 38          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.004416254 |
# |    clip_fraction        | 0.0395      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.821      |
# |    explained_variance   | 0.0196      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 147         |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00124    |
# |    value_loss           | 1.28e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8           |
# |    ep_rew_mean          | -31.6       |
# | time/                   |             |
# |    fps                  | 2929        |
# |    iterations           | 39          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.007215068 |
# |    clip_fraction        | 0.0272      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.799      |
# |    explained_variance   | 0.0166      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.31e+04    |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00194    |
# |    value_loss           | 1.03e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8           |
# |    ep_rew_mean          | -49.6       |
# | time/                   |             |
# |    fps                  | 2930        |
# |    iterations           | 40          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.008345931 |
# |    clip_fraction        | 0.0805      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.709      |
# |    explained_variance   | 0.00716     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.21e+03    |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00473    |
# |    value_loss           | 7.8e+03     |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 8             |
# |    ep_rew_mean          | -70.2         |
# | time/                   |               |
# |    fps                  | 2931          |
# |    iterations           | 41            |
# |    time_elapsed         | 28            |
# |    total_timesteps      | 83968         |
# | train/                  |               |
# |    approx_kl            | 0.00064366934 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.69         |
# |    explained_variance   | 0.00472       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.79e+03      |
# |    n_updates            | 400           |
# |    policy_gradient_loss | -0.0007       |
# |    value_loss           | 2.28e+04      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8           |
# |    ep_rew_mean          | -30.8       |
# | time/                   |             |
# |    fps                  | 2930        |
# |    iterations           | 42          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.004150031 |
# |    clip_fraction        | 0.0615      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.714      |
# |    explained_variance   | 0.0124      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.15e+04    |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00238    |
# |    value_loss           | 2.99e+04    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 8             |
# |    ep_rew_mean          | -40.7         |
# | time/                   |               |
# |    fps                  | 2929          |
# |    iterations           | 43            |
# |    time_elapsed         | 30            |
# |    total_timesteps      | 88064         |
# | train/                  |               |
# |    approx_kl            | 0.00015644508 |
# |    clip_fraction        | 0.00923       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.743        |
# |    explained_variance   | 0.0177        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.9e+03       |
# |    n_updates            | 420           |
# |    policy_gradient_loss | 0.00021       |
# |    value_loss           | 1.03e+04      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8           |
# |    ep_rew_mean          | -31.4       |
# | time/                   |             |
# |    fps                  | 2929        |
# |    iterations           | 44          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.006159296 |
# |    clip_fraction        | 0.0926      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.738      |
# |    explained_variance   | 0.0109      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.64e+03    |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00184    |
# |    value_loss           | 1.53e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8           |
# |    ep_rew_mean          | -40.9       |
# | time/                   |             |
# |    fps                  | 2928        |
# |    iterations           | 45          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.008792907 |
# |    clip_fraction        | 0.0517      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.687      |
# |    explained_variance   | 0.0236      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 73.2        |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00531    |
# |    value_loss           | 7.73e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8           |
# |    ep_rew_mean          | -40.9       |
# | time/                   |             |
# |    fps                  | 2926        |
# |    iterations           | 46          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.006171261 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.695      |
# |    explained_variance   | 0.00793     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.92e+04    |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00314    |
# |    value_loss           | 1.53e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8           |
# |    ep_rew_mean          | -100        |
# | time/                   |             |
# |    fps                  | 2926        |
# |    iterations           | 47          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.008156892 |
# |    clip_fraction        | 0.0502      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.651      |
# |    explained_variance   | 0.0114      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.1e+03     |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00275    |
# |    value_loss           | 1.03e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8           |
# |    ep_rew_mean          | -41.2       |
# | time/                   |             |
# |    fps                  | 2923        |
# |    iterations           | 48          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.009777093 |
# |    clip_fraction        | 0.0856      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.676      |
# |    explained_variance   | 0.0132      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.38e+03    |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00372    |
# |    value_loss           | 2.98e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8           |
# |    ep_rew_mean          | -41.9       |
# | time/                   |             |
# |    fps                  | 2923        |
# |    iterations           | 49          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.007931623 |
# |    clip_fraction        | 0.0409      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.718      |
# |    explained_variance   | 0.0188      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1e+04       |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00201    |
# |    value_loss           | 2.25e+04    |
# -----------------------------------------

# %%
# After training, save the model
model.save("ppo_taxi_charging")

# %%
model = PPO.load("ppo_taxi_charging")

# %% [markdown]
# ## Test PPO model performance for 50 rounds

# %%
# Number of test episodes
num_episodes = 50

# List to store rewards for each episode
rewards = []

for episode in range(1, num_episodes + 1):
    state = vec_env.reset()
    done = False
    total_reward = 0

    while not done:
        action, _states = model.predict(state)
        state, reward, done, info = vec_env.step(action)
        total_reward += reward

    # Store the total reward for this episode
    rewards.append(total_reward)

    # Print the total reward for the current episode
    print(f"Episode {episode} - Total Reward: {total_reward}")

# Calculate the average reward
average_reward = np.mean(rewards)

print(f"\nAverage Reward over {num_episodes} episodes: {average_reward:.2f}")
# Out:
# Episode 1 - Total Reward: [-16.110022]
# Episode 2 - Total Reward: [-20.192915]
# Episode 3 - Total Reward: [-20.192915]
# Episode 4 - Total Reward: [-18.151468]
# Episode 5 - Total Reward: [-1022.2344]
# Episode 6 - Total Reward: [-18.151468]
# Episode 7 - Total Reward: [-20.192915]
# Episode 8 - Total Reward: [-21.220612]
# Episode 9 - Total Reward: [-18.151468]
# Episode 10 - Total Reward: [-20.192915]
# Episode 11 - Total Reward: [-24.275812]
# Episode 12 - Total Reward: [-24.27581]
# Episode 13 - Total Reward: [-22.234365]
# Episode 14 - Total Reward: [-16.110022]
# Episode 15 - Total Reward: [-20.192917]
# Episode 16 - Total Reward: [-20.192915]
# Episode 17 - Total Reward: [-20.192917]
# Episode 18 - Total Reward: [-20.192915]
# Episode 19 - Total Reward: [-20.192915]
# Episode 20 - Total Reward: [-24.27581]
# Episode 21 - Total Reward: [-24.275812]
# Episode 22 - Total Reward: [-22.234362]
# Episode 23 - Total Reward: [-33.328518]
# Episode 24 - Total Reward: [-18.151468]
# Episode 25 - Total Reward: [-20.192917]
# Episode 26 - Total Reward: [-24.27581]
# Episode 27 - Total Reward: [-20.192917]
# Episode 28 - Total Reward: [-24.275812]
# Episode 29 - Total Reward: [-22.234364]
# Episode 30 - Total Reward: [-20.192915]
# Episode 31 - Total Reward: [-22.234364]
# Episode 32 - Total Reward: [-24.275812]
# Episode 33 - Total Reward: [-18.151468]
# Episode 34 - Total Reward: [-20.192915]
# Episode 35 - Total Reward: [-20.192917]
# Episode 36 - Total Reward: [-20.192915]
# Episode 37 - Total Reward: [-1022.2343]
# Episode 38 - Total Reward: [-18.151468]
# Episode 39 - Total Reward: [-24.27581]
# Episode 40 - Total Reward: [-20.192915]
# Episode 41 - Total Reward: [-18.151468]
# Episode 42 - Total Reward: [-22.234362]
# Episode 43 - Total Reward: [-22.234364]
# Episode 44 - Total Reward: [-22.234364]
# Episode 45 - Total Reward: [-17.137716]
# Episode 46 - Total Reward: [-24.27581]
# Episode 47 - Total Reward: [-22.234364]
# Episode 48 - Total Reward: [-18.151468]
# Episode 49 - Total Reward: [-18.151468]
# Episode 50 - Total Reward: [-19.179163]
#
# Average Reward over 50 episodes: -61.01

# %%
# Extracting values from the numpy arrays
rewards_ppo = [reward[0] for reward in rewards]

# %%
# Plotting the rewards as a boxplot
plt.figure(figsize=(10, 1))
plt.boxplot(rewards_ppo, vert=False)
plt.title('Boxplot of Rewards over Episodes with PPO agent')
plt.xlabel('Reward')
plt.savefig('boxplot_rewards_ppo.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# # 4. Compare with random action

# %% [markdown]
# 1.  code below show each rewards if we choose random action for 50 episode, as well as the average of 50 episodes
# 2.  if the test episode include the case that energy demand is higher than the energy we have, reward will be extremely low

# %%
def test_environment(env, num_episodes=50):
    rewards = []
    
    for episode in range(num_episodes):
        state, _ = env.reset()  # Reset the environment to start a new episode
        done = False
        total_reward = 0
        
        while not done:
            action = env.action_space.sample()  # Take a random action
            next_state, reward, done, truncated, info = env.step(action)
            total_reward += reward  # Accumulate the reward
            state = next_state  # Move to the next state
        
        rewards.append(total_reward)  # Store the total reward for this episode
        print(f"Episode {episode + 1} - Total Reward: {total_reward}")

    average_reward = np.mean(rewards)  # Calculate the average reward
    print(f"Average Reward over {num_episodes} episodes: {average_reward}")
    return rewards

# Test the environment with random actions for 50 episodes
rewards_random = test_environment(env, num_episodes=50)
# Out:
# Episode 1 - Total Reward: -29.132732380653874
# Episode 2 - Total Reward: -37.157745880087994
# Episode 3 - Total Reward: -33.201685054969026
# Episode 4 - Total Reward: -31.174179640028072
# Episode 5 - Total Reward: -36.27082686624694
# Episode 6 - Total Reward: -54.23546743085996
# Episode 7 - Total Reward: -45.18275937952212
# Episode 8 - Total Reward: -42.25439310630687
# Episode 9 - Total Reward: -30.14648508812435
# Episode 10 - Total Reward: -29.132732380653874
# Episode 11 - Total Reward: -28.105037828750152
# Episode 12 - Total Reward: -23.149166140593948
# Episode 13 - Total Reward: -27.204176970475853
# Episode 14 - Total Reward: -30.14648508812435
# Episode 15 - Total Reward: -37.157745880087994
# Episode 16 - Total Reward: -15.11021079672658
# Episode 17 - Total Reward: -36.2568850218137
# Episode 18 - Total Reward: -35.24313231434322
# Episode 19 - Total Reward: -26.20436610743862
# Episode 20 - Total Reward: -15.110210796726584
# Episode 21 - Total Reward: -29.132732380653874
# Episode 22 - Total Reward: -51.18026746401529
# Episode 23 - Total Reward: -29.11879053622063
# Episode 24 - Total Reward: -35.36996600797265
# Episode 25 - Total Reward: -33.201685054969026
# Episode 26 - Total Reward: -44.169006672051644
# Episode 27 - Total Reward: -27.105226965712916
# Episode 28 - Total Reward: -44.16900667205164
# Episode 29 - Total Reward: -31.160237795594824
# Episode 30 - Total Reward: -23.135224296160704
# Episode 31 - Total Reward: -34.22937960687275
# Episode 32 - Total Reward: -27.091285121279675
# Episode 33 - Total Reward: -28.231871522379578
# Episode 34 - Total Reward: -29.132732380653874
# Episode 35 - Total Reward: -37.157745880087994
# Episode 36 - Total Reward: -29.13273238065387
# Episode 37 - Total Reward: -33.21562689940227
# Episode 38 - Total Reward: -34.102545913243326
# Episode 39 - Total Reward: -20.206858022945454
# Episode 40 - Total Reward: -37.157745880087994
# Episode 41 - Total Reward: -35.13024046514704
# Episode 42 - Total Reward: -25.176671555534902
# Episode 43 - Total Reward: -27.2181188149091
# Episode 44 - Total Reward: -37.157745880087994
# Episode 45 - Total Reward: -25.176671555534902
# Episode 46 - Total Reward: -25.176671555534902
# Episode 47 - Total Reward: -33.201685054969026
# Episode 48 - Total Reward: -28.118979673183397
# Episode 49 - Total Reward: -24.162918848064425
# Episode 50 - Total Reward: -26.204366107438624
# Average Reward over 50 episodes: -31.714023222318964

# %%
# Extracting values from the numpy arrays
rewards_random
# Out:
# [-29.132732380653874,
#  -37.157745880087994,
#  -33.201685054969026,
#  -31.174179640028072,
#  -36.27082686624694,
#  -54.23546743085996,
#  -45.18275937952212,
#  -42.25439310630687,
#  -30.14648508812435,
#  -29.132732380653874,
#  -28.105037828750152,
#  -23.149166140593948,
#  -27.204176970475853,
#  -30.14648508812435,
#  -37.157745880087994,
#  -15.11021079672658,
#  -36.2568850218137,
#  -35.24313231434322,
#  -26.20436610743862,
#  -15.110210796726584,
#  -29.132732380653874,
#  -51.18026746401529,
#  -29.11879053622063,
#  -35.36996600797265,
#  -33.201685054969026,
#  -44.169006672051644,
#  -27.105226965712916,
#  -44.16900667205164,
#  -31.160237795594824,
#  -23.135224296160704,
#  -34.22937960687275,
#  -27.091285121279675,
#  -28.231871522379578,
#  -29.132732380653874,
#  -37.157745880087994,
#  -29.13273238065387,
#  -33.21562689940227,
#  -34.102545913243326,
#  -20.206858022945454,
#  -37.157745880087994,
#  -35.13024046514704,
#  -25.176671555534902,
#  -27.2181188149091,
#  -37.157745880087994,
#  -25.176671555534902,
#  -25.176671555534902,
#  -33.201685054969026,
#  -28.118979673183397,
#  -24.162918848064425,
#  -26.204366107438624]

# %%
# Plotting the rewards as a boxplot
plt.figure(figsize=(10, 1))
plt.boxplot(rewards_random, vert=False)
plt.title('Boxplot of Rewards over Episodes with random selection of charging policy')
plt.xlabel('Reward')
plt.savefig('boxplot_rewards_random.png', bbox_inches='tight')
plt.show()

# %%
# Generate requirements.txt file
import subprocess

# Run 'pip freeze' and capture the output
result = subprocess.run(['pip', 'freeze'], stdout=subprocess.PIPE, text=True)

# Write the output to 'requirements.txt'
with open('requirements_RL.txt', 'w') as f:
    f.write(result.stdout)

print("requirements.txt has been generated.")
# Out:
# requirements.txt has been generated.
