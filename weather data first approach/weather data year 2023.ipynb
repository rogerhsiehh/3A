# %%
import requests
import pandas as pd

# Define your API token
api_token = 'auWgjXaVIEXjrMEsJeswcOARaOpmaUzi'

# Define the endpoint and parameters
endpoint = 'https://www.ncei.noaa.gov/access/services/data/v1'
headers = {'token': api_token}

# Parameters for the request
params = {
    'dataset': 'GHCND',
    'locationid': 'CITY:US170006',  # Chicago's location ID
    'startdate': '2023-01-01',
    'enddate': '2023-12-31',
    'units': 'metric',
    'limit': 1000  # NOAA API has a limit per request, use pagination if needed
}

# Make the API request
url = endpoint
response = requests.get(url, headers=headers, params=params)

# Check if the request was successful
if response.status_code == 200:
    data = response.json()
    print(data)
else:
    print(f"Error: {response.status_code}")
# Out:
# {'metadata': {'resultset': {'offset': 1, 'count': 108903, 'limit': 1000}}, 'results': [{'date': '2023-01-01T00:00:00', 'datatype': 'PRCP', 'station': 'GHCND:US1ILCK0012', 'attributes': ',,N,0730', 'value': 3.0}, {'date': '2023-01-01T00:00:00', 'datatype': 'PRCP', 'station': 'GHCND:US1ILCK0014', 'attributes': ',,N,0600', 'value': 3.6}, {'date': '2023-01-01T00:00:00', 'datatype': 'PRCP', 'station': 'GHCND:US1ILCK0042', 'attributes': ',,N,0700', 'value': 3.8}, {'date': '2023-01-01T00:00:00', 'datatype': 'SNOW', 'station': 'GHCND:US1ILCK0042', 'attributes': ',,N,0700', 'value': 0.0}, {'date': '2023-01-01T00:00:00', 'datatype': 'PRCP', 'station': 'GHCND:US1ILCK0050', 'attributes': ',,N,0700', 'value': 3.6}, {'date': '2023-01-01T00:00:00', 'datatype': 'PRCP', 'station': 'GHCND:US1ILCK0063', 'attributes': ',,N,0700', 'value': 3.3}, {'date': '2023-01-01T00:00:00', 'datatype': 'PRCP', 'station': 'GHCND:US1ILCK0064', 'attributes': ',,N,0700', 'value': 0.8}, {'date': '2023-01-01T00:00:00', 'dat
# ...

# %% [markdown]
# **this api do not contain the hourly weather data in 2023**, for 'dataset:NORMAL_HLY' it only provide the year from 1981-2010. At the end we choose meteostat api instead
